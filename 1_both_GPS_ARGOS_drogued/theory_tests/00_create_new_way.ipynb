# %%
import numpy as np
import pandas as pd
import xarray as xr
import pyproj
from rasterio.transform import Affine

import dask.dataframe as dd
import matplotlib.pyplot as plt
import matplotlib.colors as cl

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.geodesic as cgeo

crs = ccrs.PlateCarree()
import cmocean.cm as cm

from xgcm import Grid
from xhistogram.xarray import histogram
import warnings

warnings.filterwarnings("ignore")

import os
from glob import glob

import histlib.box as box
import histlib.aviso as aviso
import histlib.cstes as cstes
import histlib.diagnosis as diag
from histlib.cstes import labels, zarr_dir, matchup_dir
# Out:
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.scheduler.transition-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(
# /home1/datahome/mdemol/.miniconda3/envs/histenv2/lib/python3.9/site-packages/dask/config.py:742: FutureWarning: Dask configuration key 'distributed.comm.recent-messages-log-length' has been deprecated; please use 'distributed.admin.low-level-log-length' instead
#   warnings.warn(

# %%
if True:
    from dask.distributed import Client
    from dask_jobqueue import PBSCluster

    # cluster = PBSCluster(cores=56, processes=28, walltime='04:00:00')
    # cluster = PBSCluster(cores=7, processes=7, walltime='04:00:00')
    cluster = PBSCluster(cores=5, processes=5, walltime="02:00:00")
    w = cluster.scale(jobs=4)
    # w = cluster.scale(jobs=3)
else:
    from dask.distributed import Client, LocalCluster

    cluster = LocalCluster()

client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.148.0.73:57921' processes=0 threads=0, memory=0 B>

# %% [markdown]
# # Create csv files

# %%
zarrs_cutoff = sorted(
    glob(
        os.path.join(
            "/home/datawork-lops-osi/aponte/margot/historical_coloc_ok/cutoff_matchup",
            "*_2.zarr",
        )
    )
)

# %%
zarrs = sorted(
    glob(
        os.path.join(
            "/home/datawork-lops-osi/aponte/margot/historical_coloc_ok/matchup", "*"
        )
    )
)

# %%
for i in range(len(zarrs)):
    ds0 = xr.open_dataset(zarrs_cutoff[i])[
        ["drifter_acc_x_25", "drifter_coriolis_x_25"]
    ]
    ds1 = xr.open_dataset(zarrs[i])[
        [
            "drogue_status",
            "drifter_acc_x_0",
            "drifter_coriolis_x_0",
            "aviso_alti_ggx_adt",
            "aviso_drifter_ggx_adt",
            "es_cstrio_z15_drifter_wd_x",
            "es_cstrio_z15_alti_wd_x",
        ]
    ]
    path = os.path.join(
        "/home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err",
        zarrs[i].split("/")[-1].replace("zarr", "csv"),
    )
    df = xr.merge([ds0, ds1]).to_dataframe()
    df.where(df.drogue_status).dropna().to_csv(path)  # only drogued drifters
    print(path)
# Out:
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2010.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2011.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2012.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Cryosat-2_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2010.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2011.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2012.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-2_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-3_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-3_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-3_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-3_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Jason-3_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_SARAL_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_A_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_A_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_A_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_A_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_A_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_B_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_B_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_argos_Sentinel-3_B_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2010.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2011.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2012.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Cryosat-2_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2010.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2011.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2012.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-2_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-3_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-3_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-3_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-3_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Jason-3_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2013.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2014.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2015.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_SARAL_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_A_2016.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_A_2017.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_A_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_A_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_A_2020.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_B_2018.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_B_2019.csv
# /home/datawork-lops-osi/aponte/margot/historical_coloc_ok/coloc_err/matchup_gps_Sentinel-3_B_2020.csv

# %%
cluster.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cluster.close()
#
# NameError: name 'cluster' is not defined
